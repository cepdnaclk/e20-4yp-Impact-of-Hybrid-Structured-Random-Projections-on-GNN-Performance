# %%
import os

# 1. Change into the experiments directory where the code needs to run
os.chdir('/content/Impact-of-Hybrid-Structured-Random-Projections-on-GNN-Performance/code/experiments')

# 2. Install required dependencies
# !pip install optuna ogb

# 3. Verify we are in the right folder (this should print run_optuna.py, tuning.ipynb etc)
# !ls
# Out:
# ...
# nbconvert.log  run_optuna.py  tuning.ipynb

# %%
# !ls
# Out:
# nbconvert.log  run_optuna.py  tuning.ipynb

# %%
# !git clone -b cpu-time https://github.com/cepdnaclk/Impact-of-Hybrid-Structured-Random-Projections-on-GNN-Performance.git
# Out:
# Cloning into 'Impact-of-Hybrid-Structured-Random-Projections-on-GNN-Performance'...
# remote: Enumerating objects: 61, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 61 (delta 15), reused 52 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (61/61), 46.40 KiB | 2.44 MiB/s, done.
# Resolving deltas: 100% (15/15), done.

# %%
# %cd Impact-of-Hybrid-Structured-Random-Projections-on-GNN-Performance/code/experiments
# Out:
# /content/Impact-of-Hybrid-Structured-Random-Projections-on-GNN-Performance/code/experiments

# %%
# !pip install optuna ogb
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.9/413.9 kB 9.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 6.0 MB/s eta 0:00:00
# ...

# %%
# !python code/experiments/run_optuna.py
# Out:
# python3: can't open file '/content/Impact-of-Hybrid-Structured-Random-Projections-on-GNN-Performance/code/experiments/code/experiments/run_optuna.py': [Errno 2] No such file or directory

# %%
# !python run_optuna.py
# Out:
# Running on: cpu
# Loading blogcatalog...
# Traceback (most recent call last):
#   File "/content/Impact-of-Hybrid-Structured-Random-Projections-on-GNN-Performance/code/experiments/run_optuna.py", line 130, in <module>
#     main()
#   File "/content/Impact-of-Hybrid-Structured-Random-Projections-on-GNN-Performance/code/experiments/run_optuna.py", line 110, in main
#     adj, features, labels, adj_tensor, feat_tensor = load_data_for(dataset_name, data_root, device)
#                                                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Impact-of-Hybrid-Structured-Random-Projections-on-GNN-Performance/code/experiments/run_optuna.py", line 27, in load_data_for
#     adj, features, labels = load_dataset(dataset_name, root_dir=data_root)
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
# !pip install torch-geometric
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 24.6 MB/s eta 0:00:00
# ...

# %%
# %cd /content/Impact-of-Hybrid-Structured-Random-Projections-on-GNN-Performance/code/src
# !python get_flickr.py
# Out:
# /content/Impact-of-Hybrid-Structured-Random-Projections-on-GNN-Performance/code/src
# ...
# Processing...
# Done!
#    Nodes: 89250
#    Edges: 899756
#    Features: 500
# Success! Saved to /content/Impact-of-Hybrid-Structured-Random-Projections-on-GNN-Performance/code/data/flickr.mat

# %%
import os
os.chdir('/content/Impact-of-Hybrid-Structured-Random-Projections-on-GNN-Performance/code/experiments')

# Change dataset list from ['blogcatalog', 'flickr'] to just ['flickr']
with open('run_optuna.py', 'r') as f:
    content = f.read()

content = content.replace("dataset_names = ['blogcatalog', 'flickr']", "dataset_names = ['flickr']")

with open('run_optuna.py', 'w') as f:
    f.write(content)

# %%
# !python run_optuna.py
# Out:
# Running on: cpu
# Loading flickr...
# Loading flickr from .mat file...
#    Nodes: 89250, Edges: 899756
#    Labels Shape: (89250,)
#    Features loaded on GPU: torch.Size([89250, 500])
# Data preparation complete on cpu
#
# === Optuna: flickr ===
# [I 2026-03-07 04:03:17,368] A new study created in memory with name: no-name-2c921d7f-aa24-4b01-878b-db8e09b79118
# [I 2026-03-07 04:04:11,594] Trial 0 finished with value: 0.19812567660058364 and parameters: {'dim': 256, 'window_size': 4, 'normalization': True, 'g': 3}. Best is trial 0 with value: 0.19812567660058364.
# [I 2026-03-07 04:05:08,204] Trial 1 finished with value: 0.19847247457736206 and parameters: {'dim': 128, 'window_size': 3, 'normalization': True, 'g': 10}. Best is trial 1 with value: 0.19847247457736206.
# [I 2026-03-07 04:06:02,592] Trial 2 finished with value: 0.19431254289389827 and parameters: {'dim': 256, 'window_size': 3, 'normalization': False, 'g': 9}. Best is trial 1 with value: 0.19847247457736206.
# ...
