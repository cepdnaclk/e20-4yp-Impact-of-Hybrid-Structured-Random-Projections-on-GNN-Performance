# %%
# !git clone -b cpu-time https://github.com/cepdnaclk/Impact-of-Hybrid-Structured-Random-Projections-on-GNN-Performance.git
# Out:
# Cloning into 'Impact-of-Hybrid-Structured-Random-Projections-on-GNN-Performance'...
# remote: Enumerating objects: 125, done.
# remote: Counting objects: 100% (125/125), done.
# remote: Compressing objects: 100% (81/81), done.
# remote: Total 125 (delta 46), reused 106 (delta 37), pack-reused 0 (from 0)
# Receiving objects: 100% (125/125), 68.12 KiB | 1.42 MiB/s, done.
# Resolving deltas: 100% (46/46), done.

# %%
# !pip install torch_geometric
# !pip install pyg_lib torch_scatter torch_sparse torch_cluster torch_spline_conv -f https://data.pyg.org/whl/torch-2.5.0+cpu.html
# !pip install ogb optuna
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 56.4 MB/s eta 0:00:00
# ...
# Looking in links: https://data.pyg.org/whl/torch-2.5.0+cpu.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.7/547.7 kB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 10.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 792.1/792.1 kB 34.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.3/240.3 kB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.9/413.9 kB 24.3 MB/s eta 0:00:00
# ...

# %%
# %cd /content/Impact-of-Hybrid-Structured-Random-Projections-on-GNN-Performance/code
# Out:
# /content/Impact-of-Hybrid-Structured-Random-Projections-on-GNN-Performance/code

# %%
# !python -m src.get_cora
# Out:
# /usr/local/lib/python3.12/dist-packages/torch_geometric/__init__.py:4: UserWarning: An issue occurred while importing 'pyg-lib'. Disabling its usage. Stacktrace: Could not load this library: /usr/local/lib/python3.12/dist-packages/libpyg.so
#   import torch_geometric.typing
# /usr/local/lib/python3.12/dist-packages/torch_geometric/__init__.py:4: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: Could not load this library: /usr/local/lib/python3.12/dist-packages/torch_scatter/_version_cpu.so
#   import torch_geometric.typing
# /usr/local/lib/python3.12/dist-packages/torch_geometric/__init__.py:4: UserWarning: An issue occurred while importing 'torch-cluster'. Disabling its usage. Stacktrace: Could not load this library: /usr/local/lib/python3.12/dist-packages/torch_cluster/_version_cpu.so
#   import torch_geometric.typing
# ...

# %%
# !python -m src.get_citeseer
# Out:
# /usr/local/lib/python3.12/dist-packages/torch_geometric/__init__.py:4: UserWarning: An issue occurred while importing 'pyg-lib'. Disabling its usage. Stacktrace: Could not load this library: /usr/local/lib/python3.12/dist-packages/libpyg.so
#   import torch_geometric.typing
# /usr/local/lib/python3.12/dist-packages/torch_geometric/__init__.py:4: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: Could not load this library: /usr/local/lib/python3.12/dist-packages/torch_scatter/_version_cpu.so
#   import torch_geometric.typing
# /usr/local/lib/python3.12/dist-packages/torch_geometric/__init__.py:4: UserWarning: An issue occurred while importing 'torch-cluster'. Disabling its usage. Stacktrace: Could not load this library: /usr/local/lib/python3.12/dist-packages/torch_cluster/_version_cpu.so
#   import torch_geometric.typing
# ...

# %%
# !python -m src.get_pubmed
# Out:
# /usr/local/lib/python3.12/dist-packages/torch_geometric/__init__.py:4: UserWarning: An issue occurred while importing 'pyg-lib'. Disabling its usage. Stacktrace: Could not load this library: /usr/local/lib/python3.12/dist-packages/libpyg.so
#   import torch_geometric.typing
# /usr/local/lib/python3.12/dist-packages/torch_geometric/__init__.py:4: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: Could not load this library: /usr/local/lib/python3.12/dist-packages/torch_scatter/_version_cpu.so
#   import torch_geometric.typing
# /usr/local/lib/python3.12/dist-packages/torch_geometric/__init__.py:4: UserWarning: An issue occurred while importing 'torch-cluster'. Disabling its usage. Stacktrace: Could not load this library: /usr/local/lib/python3.12/dist-packages/torch_cluster/_version_cpu.so
#   import torch_geometric.typing
# ...

# %% [markdown]
# Run the cell below if any change happens to the repo

# %%
# !git pull origin cpu-time

# %%
# !python -m experiments.run_optuna_link_prediction
# Out:
# Running on: cpu
# Loading cora...
# Loading cora from .mat file...
#    Nodes: 2708, Edges: 10556
# Data preparation complete on cpu
#    Train Edges (undirected pairs): 4488
#    Test Pos Edges: 527
#    Test Neg Edges: 527
#
# === Optuna: cora (gaussian) ===
# [I 2026-03-11 04:04:18,389] A new study created in memory with name: no-name-be186b20-955e-44ff-900f-1ed641f047e7
# [I 2026-03-11 04:04:18,496] Trial 0 finished with value: 0.7119440173694502 and parameters: {'dim': 128, 'window_size': 3, 'normalization': False, 'g': 4}. Best is trial 0 with value: 0.7119440173694502.
# [I 2026-03-11 04:04:18,554] Trial 1 finished with value: 0.7121348508798145 and parameters: {'dim': 64, 'window_size': 4, 'normalization': False, 'g': 2}. Best is trial 1 with value: 0.7121348508798145.
# [I 2026-03-11 04:04:18,754] Trial 2 finished with value: 0.8359101858286315 and parameters: {'dim': 512, 'window_size': 4, 'normalization': True, 'g': 10}. Best is trial 2 with value: 0.8359101858286315.
# ...

# %%
# !git pull origin cpu-time
# Out:
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 5 (delta 3), reused 5 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 850 bytes | 77.00 KiB/s, done.
# From https://github.com/cepdnaclk/Impact-of-Hybrid-Structured-Random-Projections-on-GNN-Performance
#  * branch            cpu-time   -> FETCH_HEAD
#    75e0ca3..0e3ae0c  cpu-time   -> origin/cpu-time
# Updating 75e0ca3..0e3ae0c
# Fast-forward
#  code/experiments/run_optuna_link_prediction.py | 31 ++++++++++++++++++--------
#  1 file changed, 22 insertions(+), 9 deletions(-)

# %%
# !python -m experiments.run_optuna_link_prediction
# Out:
# Running on: cpu
# Loading cora...
# Loading cora from .mat file...
#    Nodes: 2708, Edges: 10556
# Data preparation complete on cpu
#    Train Edges (undirected pairs): 4488
#    Test Pos Edges: 527
#    Test Neg Edges (per positive): 500
#
# === Optuna: cora (gaussian) ===
# [I 2026-03-11 04:37:11,958] A new study created in memory with name: no-name-c9e0c056-bf96-42c4-bc8b-8b80721a7288
# [I 2026-03-11 04:37:14,032] Trial 0 finished with value: 0.794413446201153 and parameters: {'dim': 512, 'window_size': 5, 'normalization': False, 'g': 9}. Best is trial 0 with value: 0.794413446201153.
# [I 2026-03-11 04:37:14,435] Trial 1 finished with value: 0.6946899855614647 and parameters: {'dim': 128, 'window_size': 2, 'normalization': False, 'g': 7}. Best is trial 0 with value: 0.794413446201153.
# ...

# %%
# !git pull origin cpu-time
# Out:
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 5 (delta 3), reused 5 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 1.35 KiB | 459.00 KiB/s, done.
# From https://github.com/cepdnaclk/Impact-of-Hybrid-Structured-Random-Projections-on-GNN-Performance
#  * branch            cpu-time   -> FETCH_HEAD
#    0e3ae0c..46505a2  cpu-time   -> origin/cpu-time
# Updating 0e3ae0c..46505a2
# Fast-forward
#  code/experiments/run_optuna_link_prediction.py | 105 ++++++++++++++++++-------
#  1 file changed, 78 insertions(+), 27 deletions(-)

# %%
# !python -m experiments.run_optuna_link_prediction
# Out:
# Running on: cpu
# Loading cora...
# Loading cora from .mat file...
#    Nodes: 2708, Edges: 10556
# Data preparation complete on cpu
#    Train Edges (undirected pairs): 4488
#    Val Pos Edges: 263
#    Test Pos Edges: 527
#
# === Optuna: cora (gaussian) ===
# [I 2026-03-11 06:28:57,521] A new study created in memory with name: no-name-2aa97ef7-f979-40ab-97d9-206ba8391010
# [I 2026-03-11 06:28:57,920] Trial 0 finished with value: 0.04584766794066919 and parameters: {'dim': 64, 'window_size': 3, 'normalization': False, 'g': 4}. Best is trial 0 with value: 0.04584766794066919.
# [I 2026-03-11 06:29:00,187] Trial 1 finished with value: 0.3126486136432836 and parameters: {'dim': 512, 'window_size': 5, 'normalization': True, 'g': 5}. Best is trial 1 with value: 0.3126486136432836.
# [I 2026-03-11 06:29:00,892] Trial 2 finished with value: 0.11242078918921176 and parameters: {'dim': 512, 'window_size': 4, 'normalization': False, 'g': 5}. Best is trial 1 with value: 0.3126486136432836.
# ...
